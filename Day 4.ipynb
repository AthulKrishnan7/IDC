# %%
df = spark.read \
.format('csv') \
.option('header','True') \
.load('/Volumes/practice/default/dataframe_ops')

display(df)

# %%
df.write \
.mode('overwrite') \
.format('delta') \
.save('/Volumes/practice/default/dataframe_ops/delta')

# %%
try:
    wrong_schema = spark.createDataFrame([("a","b","c")], ["x","y","z"])
    wrong_schema.write.format("delta").mode("append").save("/Volumes/practice/default/dataframe_ops/delta")
except Exception as e:
    print(f"Schema enforcement: {e}")
