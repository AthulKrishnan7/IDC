# %%
from delta.tables import DeltaTable

# %%
delta = DeltaTable.forPath(spark, "/Volumes/practice/default/dataframe_ops/delta")

# %%
# %sql
select * from delta.`/Volumes/practice/default/dataframe_ops/delta`limit 10

# %%
# %sql
UPDATE delta.`/Volumes/practice/default/dataframe_ops/delta`
SET gender = 'Tech'
WHERE region = 1000;

# %%
df = spark.read \
.format('csv') \
.option('header','True') \
.load('/Volumes/practice/default/dataframe_ops')

# %%
delta.alias("t").merge(
    df.alias("s"),
    "t.Region = s.Region "
).whenMatchedUpdateAll() \
 .whenNotMatchedInsertAll() \
 .execute()

# %%
# Time travel
v0 = spark.read.format("delta").option("versionAsOf", 0).load("/delta/events")
yesterday = spark.read.format("delta") \
    .option("timestampAsOf", "2024-01-01").load("/delta/events")

# Optimize
spark.sql("OPTIMIZE events_table ZORDER BY (event_type, user_id)")
spark.sql("VACUUM events_table RETAIN 168 HOURS")
